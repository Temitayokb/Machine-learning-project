# %% [markdown]
# ### PROJECT BY TEMITAYO KEN-BRAIMOH
# DATA SCIENCE: MACHINE LEARNING
#
# ### REASON FOR CHOSING ABALONE:
#
# I am an environmentalist and love nature, the prediction of the age of abalone using physical measurments seems to be a saver method than putting abolone at the risk of death due to the rigorous process involved in counting the number of rings And as a beginner in machine learning the dataset is easy to work with because it requires less cleaning process.
#
#
# #### AGE OF ABALONE
# Problem involves Predicting the age of abalone from physical measurements.
# To be able solve this problem, a model needs to be trained to identity the age of
# the abalone based on the available data contained therein.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
# !pip install seaborn
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
## importation of dataset to Vscode
pd.read_csv("abalone.data")
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
Abalone = pd.read_csv("abalone.data")

# %%
## Data Cleaning and Exploration
Abalone.head(5)
# Out:
#    M  0.455  0.365  0.095   0.514  0.2245   0.101   0.15  15
# 0  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 1  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 2  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 3  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7
# 4  I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.120   8

# %%
Abalone
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
data_name = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight','Viscera weight', 'Shell weight', 'Rings' ]

# %%
Abalone.columns = data_name

# %%
Abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4176 entries, 0 to 4175
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4176 non-null   object
#  1   Length          4176 non-null   float64
#  2   Diameter        4176 non-null   float64
#  3   Height          4176 non-null   float64
#  4   Whole weight    4176 non-null   float64
#  5   Shucked weight  4176 non-null   float64
#  6   Viscera weight  4176 non-null   float64
#  7   Shell weight    4176 non-null   float64
#  8   Rings           4176 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
Abalone.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 1   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 2   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 3   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 4   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
#
#    Shell weight  Rings
# 0         0.070      7
# 1         0.210      9
# 2         0.155     10
# 3         0.055      7
# 4         0.120      8

# %%
Abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4176.000000  4176.000000  4176.000000   4176.000000      4176.00000
# mean      0.524009     0.407892     0.139527      0.828818         0.35940
# std       0.120103     0.099250     0.041826      0.490424         0.22198
# min       0.075000     0.055000     0.000000      0.002000         0.00100
# 25%       0.450000     0.350000     0.115000      0.441500         0.18600
# 50%       0.545000     0.425000     0.140000      0.799750         0.33600
# 75%       0.615000     0.480000     0.165000      1.153250         0.50200
# max       0.815000     0.650000     1.130000      2.825500         1.48800
#
#        Viscera weight  Shell weight        Rings
# count     4176.000000   4176.000000  4176.000000
# mean         0.180613      0.238852     9.932471
# std          0.109620      0.139213     3.223601
# min          0.000500      0.001500     1.000000
# ...

# %%
### Data visualization

# %%
plt.scatter(Abalone['Whole weight'], Abalone['Shucked weight'])
plt.xlabel('Whole weight')
plt.ylabel('Shucked weight')
# Out:
# Text(0, 0.5, 'Shucked weight')

# %%
plt.scatter(Abalone['Whole weight'], Abalone['Viscera weight'])
plt.xlabel('Whole weight')
plt.ylabel('Viscera weight')
# Out:
# Text(0, 0.5, 'Viscera weight')

# %%
plt.scatter(Abalone['Diameter'], Abalone['Rings'])
plt.xlabel('Diameter')
plt.ylabel('Rings')
# Out:
# Text(0, 0.5, 'Rings')

# %%
plt.scatter(Abalone['Height'], Abalone['Whole weight'])
plt.xlabel('Height')
plt.ylabel('Whole weight')
plt.scatter(Abalone['Diameter'], Abalone['Whole weight'])
plt.xlabel('Diameter')
plt.ylabel('Whole weight')
# Out:
# Text(0, 0.5, 'Whole weight')

# %%
Abalone['Sex'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
Abalone['Sex'].value_counts().plot.pie()
plt.legend()

# %%
sns.heatmap(Abalone.drop('Sex', axis=1).corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize= (10,8))
plt.boxplot(Abalone.drop(['Sex', 'Rings'], axis=1))
plt.xticks([1,2,3,4,5,6,7],['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight','Viscera weight', 'Shell weight'])
plt.ylabel('values')
plt.xlabel('Variables')
plt.title('Boxplot of Variables')
plt.show()

# %%
### Transformation of categorical data to become numeric
df = pd.get_dummies(Abalone)
df.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 1   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 2   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 3   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 4   0.425     0.300   0.095        0.3515          0.1410          0.0775
#
#    Shell weight  Rings  Sex_F  Sex_I  Sex_M
# 0         0.070      7  False  False   True
# 1         0.210      9   True  False  False
# 2         0.155     10  False  False   True
# 3         0.055      7  False   True  False
# 4         0.120      8  False   True  False

# %%
### Data training Process
X=df.drop('Rings', axis=1)
y=df['Rings']
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size= 0.2, shuffle=True, random_state=42)

# %%
Random=RandomForestRegressor()
Random.fit(X=X_train,y=y_train)
# Out:
# RandomForestRegressor()

# %%
ypred=Random.predict(X_test)

# %%
mean_absolute_error(y_test, ypred)
# Out:
# 1.5322846889952153

# %%
scaler = StandardScaler()
X_trainscaled=scaler.fit_transform(X=X_train)
X_testscaled=scaler.transform(X_test)

# %%
Random.fit(X=X_trainscaled,y=y_train)
# Out:
# RandomForestRegressor()

# %%
ypred=Random.predict(X_testscaled)

# %%
mean_absolute_error(y_test, ypred)
# Out:
# 1.540598086124402

# %%
ridge=Ridge()
ridge.fit(X=X_train,y=y_train)
# Out:
# Ridge()

# %%
ypred=ridge.predict(X_test)
mean_absolute_error(y_test, ypred)
# Out:
# 1.5740379639637283

# %%
linear=LinearRegression()
linear.fit(X=X_train,y=y_train)
ypred=linear.predict(X_test)
mean_absolute_error(y_test, ypred)
# Out:
# 1.564326966208134

# %% [markdown]
# Finally, for the identication of Abalone's age, the model trained with RandomForestRegressor is chosen
# because its the one with result closeset to zero and the best performing model.
